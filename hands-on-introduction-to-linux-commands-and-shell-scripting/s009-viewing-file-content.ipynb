# %% [markdown]
# # Viewing complete file content all at once

# %% [markdown]
# ![image.png](attachment:2b308153-ad3e-4a1b-833b-12d0a868a2b3.png)

# %% [markdown]
# # Viewing your file page-by-page

# %% [markdown]
# When you click the **space bar**, you will see the **next page**, which displays the numbers **9-17**.
#
# Entering **q** quits the `more` program and returns you to the command prompt.
#
# ![image.png](attachment:ca4a9085-97f6-4012-9bc6-34f37017d0e4.png)

# %% [markdown]
# # Viewing the first N lines

# %% [markdown]
# **`head`**:
# * By default, it prints the **first 10 lines** of the file.
# * You can specify the number of lines you would like the `head` to return using the `-n` option.
#
# ![image.png](attachment:da832ddc-fb40-4f2b-8080-7e697825286f.png)
#
# ![image.png](attachment:060b639e-44b5-476f-b2b7-d5b9a3650ad8.png)

# %% [markdown]
# # Viewing the last N lines of a file

# %% [markdown]
# **`tail`**:
# * By default, it prints the **last 10 lines** of the file.
# * You can specify the number of lines you would like the `tail` to return using the `-n` option.
#
# ![image.png](attachment:54cccaaa-59f5-42ce-9391-e8cda4622d54.png)
#
# ![image.png](attachment:48c6a1f8-7d43-4209-95bf-8cf18c8b529b.png)

# %% [markdown]
# # Counting lines, words, and characters

# %% [markdown]
# ![image.png](attachment:344bace8-65eb-4833-bf71-18601075badd.png)
#
# You can use the `wc` command to **count the number of characters, words, or lines** in your file.
#
# Imagine you have a file called **`pets.txt`**.
# * Entering `cat pets.txt` shows that the file contains the word cat or the word dog on each line.
# * By entering `wc pets.txt`, you get the result `7 7 28 pets.txt`.
# * This means that your file contains 7 lines, 7 words, and 28 characters.
#
# **But 7 times 3 is 21, so why does wc see 28 characters?**
# * Because it also counts newline characters.
# * You can't see them there, but there are **seven new line characters**, one of which represents the end of the file.
#
# To view only line count, you can use the `-l` option, which returns `7 pets.txt`.
#
# Similarly, to view only word count, you can use the `-w` option.
#
# To view only character count, you can use the `-c` option.
